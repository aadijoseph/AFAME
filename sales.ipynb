# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("C:/Users/Adithya Joseph/Downloads/ECOMM DATA.csv")

# %%
df.head()
# Out:
#    Row ID         Order ID  Order Date   Ship Date     Ship Mode Customer ID  \
# 0   32298   CA-2012-124891   7/31/2012   7/31/2012      Same Day    RH-19495
# 1   26341    IN-2013-77878    2/5/2013    2/7/2013  Second Class    JR-16210
# 2   25330    IN-2013-71249  10/17/2013  10/18/2013   First Class    CR-12730
# 3   13524  ES-2013-1579342   1/28/2013   1/30/2013   First Class    KM-16375
# 4   47221     SG-2013-4320   11/5/2013   11/6/2013      Same Day     RH-9495
#
#       Customer Name      Segment           City            State  ...  \
# 0       Rick Hansen     Consumer  New York City         New York  ...
# 1     Justin Ritter    Corporate     Wollongong  New South Wales  ...
# 2      Craig Reiter     Consumer       Brisbane       Queensland  ...
# 3  Katherine Murray  Home Office         Berlin           Berlin  ...
# 4       Rick Hansen     Consumer          Dakar            Dakar  ...
#
#          Product ID    Category Sub-Category  \
# ...

# %%
df.shape
# Out:
# (51290, 24)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          51290 non-null  int64
#  1   Order ID        51290 non-null  object
#  2   Order Date      51290 non-null  object
#  3   Ship Date       51290 non-null  object
#  4   Ship Mode       51290 non-null  object
#  5   Customer ID     51290 non-null  object
#  6   Customer Name   51290 non-null  object
#  7   Segment         51290 non-null  object
#  8   City            51290 non-null  object
#  9   State           51290 non-null  object
#  10  Country         51290 non-null  object
#  11  Postal Code     9994 non-null   float64
#  12  Market          51290 non-null  object
#  13  Region          51290 non-null  object
#  14  Product ID      51290 non-null  object
#  15  Category        51290 non-null  object
#  16  Sub-Category    51290 non-null  object
# ...

# %%
df.isnull().sum()
# Out:
# Row ID                0
# Order ID              0
# Order Date            0
# Ship Date             0
# Ship Mode             0
# Customer ID           0
# Customer Name         0
# Segment               0
# City                  0
# State                 0
# Country               0
# Postal Code       41296
# Market                0
# Region                0
# Product ID            0
# Category              0
# Sub-Category          0
# Product Name          0
# Sales                 0
# Quantity              0
# Discount              0
# Profit                0
# Shipping Cost         0
# Order Priority        0
# dtype: int64

# %%
df.describe().transpose()
# Out:
#                  count          mean           std       min           25%  \
# Row ID         51290.0  25645.500000  14806.291990     1.000  12823.250000
# Postal Code     9994.0  55190.379428  32063.693350  1040.000  23223.000000
# Sales          51290.0    246.490581    487.565361     0.444     30.758625
# Quantity       51290.0      3.476545      2.278766     1.000      2.000000
# Discount       51290.0      0.142908      0.212280     0.000      0.000000
# Profit         51290.0     28.610982    174.340972 -6599.978      0.000000
# Shipping Cost  51290.0     26.375907     57.296805     0.000      2.610000
#
#                      50%         75%        max
# Row ID         25645.500  38467.7500  51290.000
# Postal Code    56430.500  90008.0000  99301.000
# Sales             85.053    251.0532  22638.480
# Quantity           3.000      5.0000     14.000
# Discount           0.000      0.2000      0.850
# Profit             9.240     36.8100   8399.976
# ...

# %%
df.drop(["Postal Code"], axis = 1)
# Out:
#        Row ID         Order ID  Order Date   Ship Date       Ship Mode  \
# 0       32298   CA-2012-124891   7/31/2012   7/31/2012        Same Day
# 1       26341    IN-2013-77878    2/5/2013    2/7/2013    Second Class
# 2       25330    IN-2013-71249  10/17/2013  10/18/2013     First Class
# 3       13524  ES-2013-1579342   1/28/2013   1/30/2013     First Class
# 4       47221     SG-2013-4320   11/5/2013   11/6/2013        Same Day
# ...       ...              ...         ...         ...             ...
# 51285   29002    IN-2014-62366   6/19/2014   6/19/2014        Same Day
# 51286   35398   US-2014-102288   6/20/2014   6/24/2014  Standard Class
# 51287   40470   US-2013-155768   12/2/2013   12/2/2013        Same Day
# 51288    9596   MX-2012-140767   2/18/2012   2/22/2012  Standard Class
# 51289    6147   MX-2012-134460   5/22/2012   5/26/2012    Second Class
#
#       Customer ID     Customer Name      Segment           City  \
# ...

# %%
df.describe(include="object")
# Out:
#               Order ID Order Date   Ship Date       Ship Mode Customer ID  \
# count            51290      51290       51290           51290       51290
# unique           25035       1430        1464               4        1590
# top     CA-2014-100111  6/18/2014  11/22/2014  Standard Class    PO-18850
# freq                14        135         130           30775          97
#
#           Customer Name   Segment           City       State        Country  \
# count             51290     51290          51290       51290          51290
# unique              795         3           3636        1094            147
# top     Muhammed Yedwab  Consumer  New York City  California  United States
# freq                108     26518            915        2001           9994
#
#        Market   Region       Product ID         Category Sub-Category  \
# count   51290    51290            51290            51290        51290
# unique      7       13            10292                3           17
# ...

# %%
#Histogram to understand the dataset
for i in df.select_dtypes(include="number").columns:
    sns.histplot(data=df,x=i)
    plt.show

# %%
df["Total_Sales"] = df["Sales"] * df["Quantity"]

# %%
df
# Out:
#        Row ID         Order ID  Order Date   Ship Date       Ship Mode  \
# 0       32298   CA-2012-124891   7/31/2012   7/31/2012        Same Day
# 1       26341    IN-2013-77878    2/5/2013    2/7/2013    Second Class
# 2       25330    IN-2013-71249  10/17/2013  10/18/2013     First Class
# 3       13524  ES-2013-1579342   1/28/2013   1/30/2013     First Class
# 4       47221     SG-2013-4320   11/5/2013   11/6/2013        Same Day
# ...       ...              ...         ...         ...             ...
# 51285   29002    IN-2014-62366   6/19/2014   6/19/2014        Same Day
# 51286   35398   US-2014-102288   6/20/2014   6/24/2014  Standard Class
# 51287   40470   US-2013-155768   12/2/2013   12/2/2013        Same Day
# 51288    9596   MX-2012-140767   2/18/2012   2/22/2012  Standard Class
# 51289    6147   MX-2012-134460   5/22/2012   5/26/2012    Second Class
#
#       Customer ID     Customer Name      Segment           City  \
# ...

# %%
sum(df["Total_Sales"])
# Out:
# 61821272.47008097

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])
# Extract year from the 'Date' column
df['Year'] = df['Order Date'].dt.year

# %%
df
# Out:
#        Row ID         Order ID Order Date   Ship Date       Ship Mode  \
# 0       32298   CA-2012-124891 2012-07-31   7/31/2012        Same Day
# 1       26341    IN-2013-77878 2013-02-05    2/7/2013    Second Class
# 2       25330    IN-2013-71249 2013-10-17  10/18/2013     First Class
# 3       13524  ES-2013-1579342 2013-01-28   1/30/2013     First Class
# 4       47221     SG-2013-4320 2013-11-05   11/6/2013        Same Day
# ...       ...              ...        ...         ...             ...
# 51285   29002    IN-2014-62366 2014-06-19   6/19/2014        Same Day
# 51286   35398   US-2014-102288 2014-06-20   6/24/2014  Standard Class
# 51287   40470   US-2013-155768 2013-12-02   12/2/2013        Same Day
# 51288    9596   MX-2012-140767 2012-02-18   2/22/2012  Standard Class
# 51289    6147   MX-2012-134460 2012-05-22   5/26/2012    Second Class
#
#       Customer ID     Customer Name      Segment           City  \
# ...

# %%
grouped_data = df.groupby(['Category', 'Year']).sum()['Total_Sales'].unstack()


# Plot the trend for each category
plt.figure(figsize=(10, 6))
for category in grouped_data.columns:
    plt.plot(grouped_data.index, grouped_data[category], label=category)

plt.title('Yearly Sales Trend by Category')
plt.xlabel('Year')
plt.ylabel('Sales')
plt.legend()
plt.grid(True)
plt.show()

# %%
grouped_data = df.groupby(['Sub-Category', 'Year']).sum()['Total_Sales'].unstack()


# Plot the trend for each category
plt.figure(figsize=(10, 6))
for category in grouped_data.columns:
    plt.plot(grouped_data.index, grouped_data[category], label=category)

plt.title('Yearly Sales Trend by Category')
plt.xlabel('Year')
plt.ylabel('Sales')
plt.legend()
plt.grid(True)
plt.show()

# %%
product_sales = df.groupby("Product Name").sum()["Total_Sales"]

# %%
best_selling_product = product_sales.idxmax()
best_product = product_sales.max()

# %%
best_selling_product
# Out:
# 'Apple Smart Phone, Full Size'

# %%
best_product
# Out:
# 432251.5012

# %%
top_10 = product_sales.sort_values(ascending = False).head(10)

# %%
top_10
# Out:
# Product Name
# Apple Smart Phone, Full Size                  432251.5012
# Motorola Smart Phone, Full Size               383074.4508
# Cisco Smart Phone, Full Size                  377353.4154
# Nokia Smart Phone, Full Size                  297163.1875
# Hon Executive Leather Armchair, Adjustable    295439.2319
# Samsung Smart Phone, VoIP                     280221.3040
# Canon imageCLASS 2200 Advanced Copier         253399.2760
# SAFCO Executive Leather Armchair, Black       253072.7100
# Samsung Smart Phone, Cordless                 245073.5400
# Nokia Smart Phone, with Caller ID             244862.2575
# Name: Total_Sales, dtype: float64

# %%
#Product Category wise Total Sales
plt.figure(figsize=(10,6))
sns.barplot(x="Sub-Category",y="Total_Sales",data = df)
plt.title = ("Product Category wise Total Sales")
plt.xlabel = ("Sub-Category")
plt.ylabel = ("Sales")
plt.xticks(rotation=45, ha='right')
plt.tight_layout(pad=2.0)
plt.show()

# %%
# Plot box plot of sales by region
plt.figure(figsize=(10, 6))
sns.boxplot(x='Category', y='Total_Sales', data=df)
plt.title('Sales Distribution by Region')
plt.xlabel('Region')
plt.ylabel('Sales')
plt.xticks(rotation=45, ha='right')
plt.tight_layout(pad=2.0)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [70], in <cell line: 4>()
#       2 plt.figure(figsize=(10, 6))
#       3 sns.boxplot(x='Category', y='Total_Sales', data=df)
# ----> 4 plt.title('Sales Distribution by Region')
#       5 plt.xlabel('Region')
#       6 plt.ylabel('Sales')
#
# TypeError: 'str' object is not callable

# %%
# Plot the histogram using Seaborn
plt.figure(figsize=(8, 6))
sns.histplot(df, bins=30, color='skyblue', edgecolor='black')
plt.title('Histogram of Random Data (Seaborn)')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [71], in <cell line: 4>()
#       2 plt.figure(figsize=(8, 6))
#       3 sns.histplot(df, bins=30, color='skyblue', edgecolor='black')
# ----> 4 plt.title('Histogram of Random Data (Seaborn)')
#       5 plt.xlabel('Value')
#       6 plt.ylabel('Frequency')
#
# TypeError: 'str' object is not callable
